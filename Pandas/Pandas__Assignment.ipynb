# %% [markdown]
# Note that the data set is not available so that don't run the cell as it will out errors

# %%
import pandas as pd
_data = pd.read_csv('t-shirts.csv')
print(_data.to_string())
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price Delivery status
# 0     2016-05-05      SDH-YU0  Yolo    L     red   spiral  14.47         damaged
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green   spiral  16.24         delayed
# 2     2016-05-07      SDH-YU2  BLOT   XL   black  Stripes  14.32       delivered
# 3     2016-05-08      SDH-YU3  Kent  XXL   green    plain  14.07         damaged
# 4     2016-05-09      SDH-YU4  BUCK   XL   white   spiral  15.56  order received
# 5     2016-05-10      SDH-YU5  BUCK    S   black  Stripes  15.38       delivered
# 6     2016-05-11      SDH-YU6  BUCK   XS     red  diamond  14.43       delivered
# 7     2016-05-12      SDH-YU7  Kent    S   white  checked  16.72       delivered
# 8     2016-05-13      SDH-YU8  Kent    M   green   spiral  16.70         damaged
# 9     2016-05-14      SDH-YU9  Wang   XL  purple   spiral  15.48         delayed
# 10    2016-05-15     SDH-YU10  Yolo   XS   green    plain  14.36        shipping
# ...

# %%
_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Date ordered     500 non-null    object
#  1   Order number     500 non-null    object
#  2   Brand            500 non-null    object
#  3   Size             500 non-null    object
#  4   Color            500 non-null    object
#  5   Design           500 non-null    object
#  6   Price            500 non-null    float64
#  7   Delivery status  500 non-null    object
# dtypes: float64(1), object(7)
# memory usage: 31.4+ KB

# %%
_data.isnull().sum()
# Out:
# Date ordered       0
# Order number       0
# Brand              0
# Size               0
# Color              0
# Design             0
# Price              0
# Delivery status    0
# dtype: int64

# %%
_data.head(10)
# Out:
#   Date ordered Order number Brand Size   Color   Design  Price Delivery status
# 0   2016-05-05      SDH-YU0  Yolo    L     red   spiral  14.47         damaged
# 1   2016-05-06      SDH-YU1  Yolo  XXL   green   spiral  16.24         delayed
# 2   2016-05-07      SDH-YU2  BLOT   XL   black  Stripes  14.32       delivered
# 3   2016-05-08      SDH-YU3  Kent  XXL   green    plain  14.07         damaged
# 4   2016-05-09      SDH-YU4  BUCK   XL   white   spiral  15.56  order received
# 5   2016-05-10      SDH-YU5  BUCK    S   black  Stripes  15.38       delivered
# 6   2016-05-11      SDH-YU6  BUCK   XS     red  diamond  14.43       delivered
# 7   2016-05-12      SDH-YU7  Kent    S   white  checked  16.72       delivered
# 8   2016-05-13      SDH-YU8  Kent    M   green   spiral  16.70         damaged
# 9   2016-05-14      SDH-YU9  Wang   XL  purple   spiral  15.48         delayed

# %%
_data.tail()# last 5 rows
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 495   2017-09-12    SDH-YU495  Wang   XS   green  diamond  15.03
# 496   2017-09-13    SDH-YU496  BUCK    M   black  Stripes  14.49
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple    plain  15.61
# 498   2017-09-15    SDH-YU498  Yolo    S     red    plain  13.49
# 499   2017-09-16    SDH-YU499  BLOT    S   black   spiral  14.75
#
#     Delivery status
# 495         damaged
# 496        shipping
# 497        shipping
# 498  order received
# 499        shipping

# %%
_data.sample(4)
# Out:
#     Date ordered Order number Brand Size  Color   Design  Price  \
# 479   2017-08-27    SDH-YU479  BUCK    S  green  diamond  13.91
# 200   2016-11-21    SDH-YU200  Kent    S    red    plain  16.67
# 236   2016-12-27    SDH-YU236  BUCK    L  black  diamond  13.98
# 372   2017-05-12    SDH-YU372  Yolo   XL  green    plain  15.91
#
#     Delivery status
# 479  order received
# 200  order received
# 236         damaged
# 372       delivered

# %%
# spcific part of th data
_data.loc[ :10 , ["Date ordered", 'Brand', 'Size']]
# Out:
#    Date ordered Brand Size
# 0    2016-05-05  Yolo    L
# 1    2016-05-06  Yolo  XXL
# 2    2016-05-07  BLOT   XL
# 3    2016-05-08  Kent  XXL
# 4    2016-05-09  BUCK   XL
# 5    2016-05-10  BUCK    S
# 6    2016-05-11  BUCK   XS
# 7    2016-05-12  Kent    S
# 8    2016-05-13  Kent    M
# 9    2016-05-14  Wang   XL
# 10   2016-05-15  Yolo   XS

# %%
print(_data["Size"].to_string())
# Out:
# 0        L
# 1      XXL
# 2       XL
# 3      XXL
# 4       XL
# 5        S
# 6       XS
# 7        S
# 8        M
# 9       XL
# 10      XS
# 11       M
# 12       L
# 13       L
# 14       M
# 15     XXL
# 16      XS
# 17       L
# 18      XS
# 19     XXL
# 20      XL
# 21      XS
# 22      XL
# 23       S
# 24      XL
# 25     XXL
# 26      XL
# 27       M
# 28      XS
# 29       S
# 30       S
# 31       M
# 32      XS
# 33      XS
# 34      XL
# 35       M
# 36       S
# 37       S
# 38       M
# 39       M
# 40      XS
# 41       L
# 42       S
# 43       S
# 44       M
# 45       M
# 46       L
# 47       M
# 48     XXL
# 49       M
# 50      XS
# 51     XXL
# 52     XXL
# 53       M
# 54     XXL
# 55     XXL
# 56      XS
# 57     XXL
# 58      XS
# 59      XL
# 60      XS
# 61       S
# 62       L
# 63       S
# 64      XS
# 65      XS
# 66       M
# 67       S
# 68       S
# 69       M
# 70       S
# 71     XXL
# 72      XS
# 73       M
# 74       M
# 75      XS
# ...

# %%
_data.iloc[20:40:2, 1:4]
# Out:
#    Order number Brand Size
# 20     SDH-YU20  BLOT   XL
# 22     SDH-YU22  BLOT   XL
# 24     SDH-YU24  Yolo   XL
# 26     SDH-YU26  Yolo   XL
# 28     SDH-YU28  Kent   XS
# 30     SDH-YU30  Wang    S
# 32     SDH-YU32  Yolo   XS
# 34     SDH-YU34  BUCK   XL
# 36     SDH-YU36  BUCK    S
# 38     SDH-YU38  Yolo    M

# %%
_data_copy = _data.copy()
_data_copy
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 0     2016-05-05      SDH-YU0  Yolo    L     red   spiral  14.47
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green   spiral  16.24
# 2     2016-05-07      SDH-YU2  BLOT   XL   black  Stripes  14.32
# 3     2016-05-08      SDH-YU3  Kent  XXL   green    plain  14.07
# 4     2016-05-09      SDH-YU4  BUCK   XL   white   spiral  15.56
# ..           ...          ...   ...  ...     ...      ...    ...
# 495   2017-09-12    SDH-YU495  Wang   XS   green  diamond  15.03
# 496   2017-09-13    SDH-YU496  BUCK    M   black  Stripes  14.49
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple    plain  15.61
# 498   2017-09-15    SDH-YU498  Yolo    S     red    plain  13.49
# 499   2017-09-16    SDH-YU499  BLOT    S   black   spiral  14.75
#
#     Delivery status
# 0           damaged
# 1           delayed
# 2         delivered
# 3           damaged
# 4    order received
# ..              ...
# 495         damaged
# ...

# %%
_data.describe()
# Out:
#             Price
# count  500.000000
# mean    15.016840
# std      1.016292
# min     12.240000
# 25%     14.307500
# 50%     14.990000
# 75%     15.622500
# max     18.030000

# %%
_data.Price.sum()
# Out:
# 7508.42

# %%
_data.loc[_data["Price"] >=10]
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 0     2016-05-05      SDH-YU0  Yolo    L     red   spiral  14.47
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green   spiral  16.24
# 2     2016-05-07      SDH-YU2  BLOT   XL   black  Stripes  14.32
# 3     2016-05-08      SDH-YU3  Kent  XXL   green    plain  14.07
# 4     2016-05-09      SDH-YU4  BUCK   XL   white   spiral  15.56
# ..           ...          ...   ...  ...     ...      ...    ...
# 495   2017-09-12    SDH-YU495  Wang   XS   green  diamond  15.03
# 496   2017-09-13    SDH-YU496  BUCK    M   black  Stripes  14.49
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple    plain  15.61
# 498   2017-09-15    SDH-YU498  Yolo    S     red    plain  13.49
# 499   2017-09-16    SDH-YU499  BLOT    S   black   spiral  14.75
#
#     Delivery status
# 0           damaged
# 1           delayed
# 2         delivered
# 3           damaged
# 4    order received
# ..              ...
# 495         damaged
# ...

# %%
_data[_data.Price>=_data.Price.mean()]
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green   spiral  16.24
# 4     2016-05-09      SDH-YU4  BUCK   XL   white   spiral  15.56
# 5     2016-05-10      SDH-YU5  BUCK    S   black  Stripes  15.38
# 7     2016-05-12      SDH-YU7  Kent    S   white  checked  16.72
# 8     2016-05-13      SDH-YU8  Kent    M   green   spiral  16.70
# ..           ...          ...   ...  ...     ...      ...    ...
# 490   2017-09-07    SDH-YU490  Wang  XXL   black  Stripes  15.87
# 493   2017-09-10    SDH-YU493  BUCK  XXL   black   spiral  16.34
# 494   2017-09-11    SDH-YU494  Kent   XS   black  diamond  15.24
# 495   2017-09-12    SDH-YU495  Wang   XS   green  diamond  15.03
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple    plain  15.61
#
#     Delivery status
# 1           delayed
# 4    order received
# 5         delivered
# 7         delivered
# 8           damaged
# ..              ...
# 490  order received
# ...

# %%
_data[_data.Price>=_data.Price.mean()].count()
# Out:
# Date ordered       245
# Order number       245
# Brand              245
# Size               245
# Color              245
# Design             245
# Price              245
# Delivery status    245
# dtype: int64

# %%
_data.sort_values('Price')# Without eny change in the data
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 363   2017-05-03    SDH-YU363  BUCK   XL  purple  diamond  12.24
# 13    2016-05-18     SDH-YU13  Yolo    L   green  diamond  12.73
# 187   2016-11-08    SDH-YU187  Wang  XXL  indigo    plain  12.74
# 182   2016-11-03    SDH-YU182  BLOT    M   white    plain  12.81
# 143   2016-09-25    SDH-YU143  BUCK   XS  indigo    plain  12.86
# ..           ...          ...   ...  ...     ...      ...    ...
# 465   2017-08-13    SDH-YU465  Kent    L   green   spiral  17.58
# 462   2017-08-10    SDH-YU462  Kent   XS  indigo  Stripes  17.61
# 131   2016-09-13    SDH-YU131  Wang    S   green  diamond  17.61
# 60    2016-07-04     SDH-YU60  Yolo   XS   white  diamond  17.90
# 415   2017-06-24    SDH-YU415  BLOT   XL     red  Stripes  18.03
#
#     Delivery status
# 363         damaged
# 13          damaged
# 187       delivered
# 182       delivered
# 143       delivered
# ..              ...
# 465  order received
# ...

# %%
_data_copy
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 0     2016-05-05      SDH-YU0  Yolo    L     red   spiral  14.47
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green   spiral  16.24
# 2     2016-05-07      SDH-YU2  BLOT   XL   black  Stripes  14.32
# 3     2016-05-08      SDH-YU3  Kent  XXL   green    plain  14.07
# 4     2016-05-09      SDH-YU4  BUCK   XL   white   spiral  15.56
# ..           ...          ...   ...  ...     ...      ...    ...
# 495   2017-09-12    SDH-YU495  Wang   XS   green  diamond  15.03
# 496   2017-09-13    SDH-YU496  BUCK    M   black  Stripes  14.49
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple    plain  15.61
# 498   2017-09-15    SDH-YU498  Yolo    S     red    plain  13.49
# 499   2017-09-16    SDH-YU499  BLOT    S   black   spiral  14.75
#
#     Delivery status
# 0           damaged
# 1           delayed
# 2         delivered
# 3           damaged
# 4    order received
# ..              ...
# 495         damaged
# ...

# %%
_data_copy.sort_values('Price', inplace = True, ascending = False)

# %%
_data_copy
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 415   2017-06-24    SDH-YU415  BLOT   XL     red  Stripes  18.03
# 60    2016-07-04     SDH-YU60  Yolo   XS   white  diamond  17.90
# 131   2016-09-13    SDH-YU131  Wang    S   green  diamond  17.61
# 462   2017-08-10    SDH-YU462  Kent   XS  indigo  Stripes  17.61
# 465   2017-08-13    SDH-YU465  Kent    L   green   spiral  17.58
# ..           ...          ...   ...  ...     ...      ...    ...
# 143   2016-09-25    SDH-YU143  BUCK   XS  indigo    plain  12.86
# 182   2016-11-03    SDH-YU182  BLOT    M   white    plain  12.81
# 187   2016-11-08    SDH-YU187  Wang  XXL  indigo    plain  12.74
# 13    2016-05-18     SDH-YU13  Yolo    L   green  diamond  12.73
# 363   2017-05-03    SDH-YU363  BUCK   XL  purple  diamond  12.24
#
#     Delivery status
# 415        shipping
# 60   order received
# 131       delivered
# 462  order received
# 465  order received
# ..              ...
# 143       delivered
# ...

# %%
del _data_copy

# %%
_data.Size.unique()
# Out:
# array(['L', 'XXL', 'XL', 'S', 'XS', 'M'], dtype=object)

# %%
_data.Size.value_counts()
# Out:
# XXL    94
# S      88
# XS     88
# M      82
# L      75
# XL     73
# Name: Size, dtype: int64

# %%
_data.groupby('Size').sum()
# Out:
#         Price
# Size
# L     1125.56
# M     1233.52
# S     1338.10
# XL    1082.90
# XS    1302.70
# XXL   1425.64

# %%
_data.groupby('Size').mean()
# Out:
#           Price
# Size
# L     15.007467
# M     15.042927
# S     15.205682
# XL    14.834247
# XS    14.803409
# XXL   15.166383

# %%
_data.groupby('Size').describe().stack()
# Out:
#                 Price
# Size
# L    count  75.000000
#      mean   15.007467
#      std     1.064385
#      min    12.730000
#      25%    14.235000
#      50%    14.860000
#      75%    15.780000
#      max    17.580000
# M    count  82.000000
#      mean   15.042927
#      std     0.877057
#      min    12.810000
#      25%    14.467500
#      50%    15.145000
#      75%    15.560000
#      max    17.080000
# S    count  88.000000
#      mean   15.205682
#      std     1.060616
#      min    13.200000
#      25%    14.495000
#      50%    15.095000
#      75%    15.740000
#      max    17.610000
# XL   count  73.000000
#      mean   14.834247
#      std     0.979227
#      min    12.240000
#      25%    14.290000
#      50%    14.790000
#      75%    15.480000
#      max    18.030000
# XS   count  88.000000
#      mean   14.803409
#      std     1.086967
#      min    12.860000
#      25%    14.140000
#      50%    14.780000
#      75%    15.380000
#      max    17.900000
# ...

# %%
_data.duplicated().sum()
# Out:
# 0

# %%
_data.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
_data.columns
# Out:
# Index(['Date ordered', 'Order number', 'Brand', 'Size', 'Color', 'Design',
#        'Price', 'Delivery status'],
#       dtype='object')

# %%
_data.keys()
# Out:
# Index(['Date ordered', 'Order number', 'Brand', 'Size', 'Color', 'Design',
#        'Price', 'Delivery status'],
#       dtype='object')

# %%
_data.values
# Out:
# array([['2016-05-05', 'SDH-YU0', 'Yolo', ..., 'spiral', 14.47, 'damaged'],
#        ['2016-05-06', 'SDH-YU1', 'Yolo', ..., 'spiral', 16.24, 'delayed'],
#        ['2016-05-07', 'SDH-YU2', 'BLOT', ..., 'Stripes', 14.32,
#         'delivered'],
#        ...,
#        ['2017-09-14', 'SDH-YU497', 'Kent', ..., 'plain', 15.61,
#         'shipping'],
#        ['2017-09-15', 'SDH-YU498', 'Yolo', ..., 'plain', 13.49,
#         'order received'],
#        ['2017-09-16', 'SDH-YU499', 'BLOT', ..., 'spiral', 14.75,
#         'shipping']], dtype=object)

# %%
_data.dtypes
# Out:
# Date ordered        object
# Order number        object
# Brand               object
# Size                object
# Color               object
# Design              object
# Price              float64
# Delivery status     object
# dtype: object

# %%
_data
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 0     2016-05-05      SDH-YU0  Yolo    L     red   spiral  14.47
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green   spiral  16.24
# 2     2016-05-07      SDH-YU2  BLOT   XL   black  Stripes  14.32
# 3     2016-05-08      SDH-YU3  Kent  XXL   green    plain  14.07
# 4     2016-05-09      SDH-YU4  BUCK   XL   white   spiral  15.56
# ..           ...          ...   ...  ...     ...      ...    ...
# 495   2017-09-12    SDH-YU495  Wang   XS   green  diamond  15.03
# 496   2017-09-13    SDH-YU496  BUCK    M   black  Stripes  14.49
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple    plain  15.61
# 498   2017-09-15    SDH-YU498  Yolo    S     red    plain  13.49
# 499   2017-09-16    SDH-YU499  BLOT    S   black   spiral  14.75
#
#     Delivery status
# 0           damaged
# 1           delayed
# 2         delivered
# 3           damaged
# 4    order received
# ..              ...
# 495         damaged
# ...

# %%
_data.drop("Design", axis = 1, inplace = False)# dropping change the main data
# Out:
#     Date ordered Order number Brand Size   Color  Price Delivery status
# 0     2016-05-05      SDH-YU0  Yolo    L     red  14.47         damaged
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green  16.24         delayed
# 2     2016-05-07      SDH-YU2  BLOT   XL   black  14.32       delivered
# 3     2016-05-08      SDH-YU3  Kent  XXL   green  14.07         damaged
# 4     2016-05-09      SDH-YU4  BUCK   XL   white  15.56  order received
# ..           ...          ...   ...  ...     ...    ...             ...
# 495   2017-09-12    SDH-YU495  Wang   XS   green  15.03         damaged
# 496   2017-09-13    SDH-YU496  BUCK    M   black  14.49        shipping
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple  15.61        shipping
# 498   2017-09-15    SDH-YU498  Yolo    S     red  13.49  order received
# 499   2017-09-16    SDH-YU499  BLOT    S   black  14.75        shipping
#
# [500 rows x 7 columns]

# %%
_data
# Out:
#     Date ordered Order number Brand Size   Color   Design  Price  \
# 0     2016-05-05      SDH-YU0  Yolo    L     red   spiral  14.47
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green   spiral  16.24
# 2     2016-05-07      SDH-YU2  BLOT   XL   black  Stripes  14.32
# 3     2016-05-08      SDH-YU3  Kent  XXL   green    plain  14.07
# 4     2016-05-09      SDH-YU4  BUCK   XL   white   spiral  15.56
# ..           ...          ...   ...  ...     ...      ...    ...
# 495   2017-09-12    SDH-YU495  Wang   XS   green  diamond  15.03
# 496   2017-09-13    SDH-YU496  BUCK    M   black  Stripes  14.49
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple    plain  15.61
# 498   2017-09-15    SDH-YU498  Yolo    S     red    plain  13.49
# 499   2017-09-16    SDH-YU499  BLOT    S   black   spiral  14.75
#
#     Delivery status
# 0           damaged
# 1           delayed
# 2         delivered
# 3           damaged
# 4    order received
# ..              ...
# 495         damaged
# ...

# %%
#dropping with change in the main data
_data.drop(columns = ['Design', 'Delivery status'], inplace = True)

# %%
_data
# Out:
#     Date ordered Order number Brand Size   Color  Price
# 0     2016-05-05      SDH-YU0  Yolo    L     red  14.47
# 1     2016-05-06      SDH-YU1  Yolo  XXL   green  16.24
# 2     2016-05-07      SDH-YU2  BLOT   XL   black  14.32
# 3     2016-05-08      SDH-YU3  Kent  XXL   green  14.07
# 4     2016-05-09      SDH-YU4  BUCK   XL   white  15.56
# ..           ...          ...   ...  ...     ...    ...
# 495   2017-09-12    SDH-YU495  Wang   XS   green  15.03
# 496   2017-09-13    SDH-YU496  BUCK    M   black  14.49
# 497   2017-09-14    SDH-YU497  Kent  XXL  purple  15.61
# 498   2017-09-15    SDH-YU498  Yolo    S     red  13.49
# 499   2017-09-16    SDH-YU499  BLOT    S   black  14.75
#
# [500 rows x 6 columns]
